# %%
import os
import numpy as np
import pandas as pd

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.ensemble import BalancedRandomForestClassifier

from sklearn.utils.class_weight import compute_class_weight

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
random_seed=1225 #10, 1225
np.random.seed(random_seed)

# %%
def perf(y, y_hat):
    print("ACC: ", round(accuracy_score(y, y_hat), 4))
    print("F1: ", round(f1_score(y, y_hat), 4))
    print("ROC AUC: ", round(roc_auc_score(y, y_hat), 4))
    print("PR: ", round(precision_score(y, y_hat), 4))

# %%
data_folder = '../data'

with open(os.path.join(data_folder, 'train_x.npy'), 'rb') as f:
    train_x = np.load(f)
with open(os.path.join(data_folder, 'train_y.npy'), 'rb') as f:
    train_y = np.load(f)
with open(os.path.join(data_folder, 'width_y.npy'), 'rb') as f:
    width_y = np.load(f)

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid, width_yt, width_yv = train_test_split(train_x, train_y, width_y, stratify=train_y, test_size=0.4)
X_valid, X_test, y_valid, y_test, width_yv, width_ytt = train_test_split(X_valid, y_valid, width_yv, stratify=y_valid, test_size=0.2)

# %%
X_train_reshape = X_train.reshape(X_train.shape[0], -1)
X_valid_reshape = X_valid.reshape(X_valid.shape[0], -1)
X_test_reshape = X_test.reshape(X_test.shape[0], -1)

y_train_reshape = y_train
y_valid_reshape = y_valid
y_test_reshape = y_test

# %%
sm = SMOTE(random_state=random_seed)
X_train_upresampled, y_train_upresampled = sm.fit_resample(X_train_reshape, y_train_reshape)

# %%
rus = RandomUnderSampler(random_state=random_seed)
X_train_downresampled, y_train_downresampled = rus.fit_resample(X_train_reshape, y_train_reshape)

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(y_train_reshape),
                                        y = y_train_reshape                                                    
                                    )
class_weights = dict(zip(np.unique(y_train_reshape), class_weights))

# %%
from sklearn.linear_model import LogisticRegression
clf_up = LogisticRegression(random_state=random_seed).fit(X_train_upresampled, y_train_upresampled)
clf_down = LogisticRegression(random_state=random_seed).fit(X_train_downresampled, y_train_downresampled)
clf_weight = LogisticRegression(random_state=random_seed, class_weight=class_weights).fit(X_train_reshape, y_train_reshape)

y_pred_up = clf_up.predict(X_test_reshape)
y_pred_down = clf_down.predict(X_test_reshape)
y_pred_weight = clf_weight.predict(X_test_reshape)

print("---Oversampling Logistic Regression---")
perf(y_test_reshape, y_pred_up)

print("---Undersampling Logistic Regression---")
perf(y_test_reshape, y_pred_down)

print("---Weighted-matrix Logistic Regression---")
perf(y_test_reshape, y_pred_weight)
# Out:
# ---Oversampling Logistic Regression---
# ACC:  0.8143
# F1:  0.3408
# ROC AUC:  0.6097
# PR:  0.3706
# ---Undersampling Logistic Regression---
# ACC:  0.7636
# F1:  0.501
# ROC AUC:  0.7702
# PR:  0.369
# ---Weighted-matrix Logistic Regression---
# ACC:  0.8107
# F1:  0.3236
# ROC AUC:  0.6002
# PR:  0.3546

# %%
from sklearn.ensemble import RandomForestClassifier

clf_up = RandomForestClassifier(random_state=random_seed).fit(X_train_upresampled, y_train_upresampled)
clf_down = RandomForestClassifier(random_state=random_seed).fit(X_train_downresampled, y_train_downresampled)
clf_weight = RandomForestClassifier(random_state=random_seed, class_weight=class_weights).fit(X_train_reshape, y_train_reshape)

y_pred_up = clf_up.predict(X_test_reshape)
y_pred_down = clf_down.predict(X_test_reshape)
y_pred_weight = clf_weight.predict(X_test_reshape)

print("---Oversampling RandomForestClassifier---")
perf(y_test_reshape, y_pred_up)

print("---Undersampling RandomForestClassifier---")
perf(y_test_reshape, y_pred_down)

print("---Weighted-matrix RandomForestClassifier---")
perf(y_test_reshape, y_pred_weight)
# Out:
# ---Oversampling RandomForestClassifier---
# ACC:  0.8351
# F1:  0.4709
# ROC AUC:  0.6903
# PR:  0.4602
# ---Undersampling RandomForestClassifier---
# ACC:  0.779
# F1:  0.5564
# ROC AUC:  0.833
# PR:  0.4005
# ---Weighted-matrix RandomForestClassifier---
# ACC:  0.8433
# F1:  0.2445
# ROC AUC:  0.5657
# PR:  0.459

# %%
from xgboost import XGBClassifier
from sklearn.utils import class_weight
class_weights = list(class_weight.compute_sample_weight(
                                        class_weight = "balanced",
                                        #classes = np.unique(y_train_reshape),
                                        y = y_train_reshape                                                    
                                    ))

clf_up = XGBClassifier(random_state=random_seed).fit(X_train_upresampled, y_train_upresampled, eval_set=[(X_valid_reshape, y_valid_reshape)])
clf_down = XGBClassifier(random_state=random_seed).fit(X_train_downresampled, y_train_downresampled, eval_set=[(X_valid_reshape, y_valid_reshape)])
clf_weight = XGBClassifier(random_state=random_seed).fit(X_train_reshape, y_train_reshape, eval_set=[(X_valid_reshape, y_valid_reshape)], sample_weight=class_weights)

y_pred_up = clf_up.predict(X_test_reshape)
y_pred_down = clf_down.predict(X_test_reshape)
y_pred_weight = clf_weight.predict(X_test_reshape)

print("---Oversampling XGBClassifier---")
perf(y_test_reshape, y_pred_up)

print("---Undersampling XGBClassifier---")
perf(y_test_reshape, y_pred_down)

print("---Weighted-matrix XGBClassifier---")
perf(y_test_reshape, y_pred_weight)
# Out:
# [0]	validation_0-logloss:0.55592
# [1]	validation_0-logloss:0.48309
# [2]	validation_0-logloss:0.43683
# [3]	validation_0-logloss:0.40460
# [4]	validation_0-logloss:0.38494
# [5]	validation_0-logloss:0.37130
# [6]	validation_0-logloss:0.36288
# [7]	validation_0-logloss:0.35749
# [8]	validation_0-logloss:0.35272
# [9]	validation_0-logloss:0.34908
# [10]	validation_0-logloss:0.34674
# [11]	validation_0-logloss:0.34424
# [12]	validation_0-logloss:0.34246
# [13]	validation_0-logloss:0.34255
# [14]	validation_0-logloss:0.34322
# [15]	validation_0-logloss:0.34249
# [16]	validation_0-logloss:0.34268
# [17]	validation_0-logloss:0.34269
# [18]	validation_0-logloss:0.34343
# [19]	validation_0-logloss:0.34325
# [20]	validation_0-logloss:0.34604
# [21]	validation_0-logloss:0.34613
# [22]	validation_0-logloss:0.34605
# [23]	validation_0-logloss:0.34680
# [24]	validation_0-logloss:0.34799
# [25]	validation_0-logloss:0.34737
# [26]	validation_0-logloss:0.34759
# [27]	validation_0-logloss:0.34820
# [28]	validation_0-logloss:0.34788
# [29]	validation_0-logloss:0.34786
# [30]	validation_0-logloss:0.34799
# [31]	validation_0-logloss:0.34915
# [32]	validation_0-logloss:0.35090
# [33]	validation_0-logloss:0.35223
# [34]	validation_0-logloss:0.35487
# [35]	validation_0-logloss:0.35568
# [36]	validation_0-logloss:0.35699
# [37]	validation_0-logloss:0.35730
# [38]	validation_0-logloss:0.35900
# [39]	validation_0-logloss:0.36167
# [40]	validation_0-logloss:0.36318
# [41]	validation_0-logloss:0.36580
# [42]	validation_0-logloss:0.36678
# [43]	validation_0-logloss:0.36850
# [44]	validation_0-logloss:0.36939
# [45]	validation_0-logloss:0.37033
# [46]	validation_0-logloss:0.37328
# [47]	validation_0-logloss:0.37453
# [48]	validation_0-logloss:0.37402
# [49]	validation_0-logloss:0.37483
# [50]	validation_0-logloss:0.37689
# [51]	validation_0-logloss:0.37830
# [52]	validation_0-logloss:0.37988
# [53]	validation_0-logloss:0.38152
# [54]	validation_0-logloss:0.38322
# [55]	validation_0-logloss:0.38447
# [56]	validation_0-logloss:0.38711
# [57]	validation_0-logloss:0.38867
# [58]	validation_0-logloss:0.38986
# [59]	validation_0-logloss:0.39192
# [60]	validation_0-logloss:0.39322
# [61]	validation_0-logloss:0.39465
# [62]	validation_0-logloss:0.39511
# [63]	validation_0-logloss:0.39578
# [64]	validation_0-logloss:0.39658
# [65]	validation_0-logloss:0.39881
# [66]	validation_0-logloss:0.40001
# [67]	validation_0-logloss:0.40084
# [68]	validation_0-logloss:0.40323
# [69]	validation_0-logloss:0.40369
# [70]	validation_0-logloss:0.40435
# [71]	validation_0-logloss:0.40461
# [72]	validation_0-logloss:0.40545
# [73]	validation_0-logloss:0.40780
# [74]	validation_0-logloss:0.40852
# [75]	validation_0-logloss:0.40982
# [76]	validation_0-logloss:0.41121
# [77]	validation_0-logloss:0.41138
# [78]	validation_0-logloss:0.41261
# [79]	validation_0-logloss:0.41298
# [80]	validation_0-logloss:0.41399
# [81]	validation_0-logloss:0.41567
# [82]	validation_0-logloss:0.41723
# [83]	validation_0-logloss:0.41809
# [84]	validation_0-logloss:0.41978
# [85]	validation_0-logloss:0.42079
# [86]	validation_0-logloss:0.42228
# [87]	validation_0-logloss:0.42458
# [88]	validation_0-logloss:0.42542
# [89]	validation_0-logloss:0.42622
# [90]	validation_0-logloss:0.42710
# [91]	validation_0-logloss:0.42832
# [92]	validation_0-logloss:0.42869
# [93]	validation_0-logloss:0.43042
# [94]	validation_0-logloss:0.43149
# [95]	validation_0-logloss:0.43223
# [96]	validation_0-logloss:0.43247
# [97]	validation_0-logloss:0.43390
# [98]	validation_0-logloss:0.43496
# [99]	validation_0-logloss:0.43623
# [0]	validation_0-logloss:0.58041
# [1]	validation_0-logloss:0.52616
# [2]	validation_0-logloss:0.49709
# [3]	validation_0-logloss:0.47453
# [4]	validation_0-logloss:0.46492
# [5]	validation_0-logloss:0.46290
# [6]	validation_0-logloss:0.45974
# [7]	validation_0-logloss:0.46198
# [8]	validation_0-logloss:0.46465
# [9]	validation_0-logloss:0.46861
# [10]	validation_0-logloss:0.46999
# [11]	validation_0-logloss:0.47211
# [12]	validation_0-logloss:0.47452
# [13]	validation_0-logloss:0.47668
# [14]	validation_0-logloss:0.48060
# [15]	validation_0-logloss:0.48547
# [16]	validation_0-logloss:0.49081
# [17]	validation_0-logloss:0.49460
# [18]	validation_0-logloss:0.50110
# [19]	validation_0-logloss:0.50421
# [20]	validation_0-logloss:0.50901
# [21]	validation_0-logloss:0.51609
# [22]	validation_0-logloss:0.52092
# [23]	validation_0-logloss:0.52748
# [24]	validation_0-logloss:0.53081
# [25]	validation_0-logloss:0.53620
# [26]	validation_0-logloss:0.54084
# [27]	validation_0-logloss:0.54501
# [28]	validation_0-logloss:0.55079
# [29]	validation_0-logloss:0.55734
# [30]	validation_0-logloss:0.55882
# [31]	validation_0-logloss:0.56311
# [32]	validation_0-logloss:0.56963
# [33]	validation_0-logloss:0.57361
# [34]	validation_0-logloss:0.57864
# [35]	validation_0-logloss:0.58536
# [36]	validation_0-logloss:0.59134
# [37]	validation_0-logloss:0.59352
# [38]	validation_0-logloss:0.59865
# [39]	validation_0-logloss:0.60251
# [40]	validation_0-logloss:0.60756
# [41]	validation_0-logloss:0.61143
# [42]	validation_0-logloss:0.61576
# [43]	validation_0-logloss:0.62044
# [44]	validation_0-logloss:0.62486
# [45]	validation_0-logloss:0.62954
# [46]	validation_0-logloss:0.63441
# [47]	validation_0-logloss:0.63749
# [48]	validation_0-logloss:0.64033
# [49]	validation_0-logloss:0.64255
# [50]	validation_0-logloss:0.64756
# [51]	validation_0-logloss:0.65111
# [52]	validation_0-logloss:0.65583
# [53]	validation_0-logloss:0.66286
# [54]	validation_0-logloss:0.66372
# [55]	validation_0-logloss:0.66413
# [56]	validation_0-logloss:0.66804
# [57]	validation_0-logloss:0.67157
# [58]	validation_0-logloss:0.67559
# [59]	validation_0-logloss:0.67960
# [60]	validation_0-logloss:0.67994
# [61]	validation_0-logloss:0.68555
# [62]	validation_0-logloss:0.68673
# [63]	validation_0-logloss:0.68776
# [64]	validation_0-logloss:0.68861
# [65]	validation_0-logloss:0.69127
# [66]	validation_0-logloss:0.69473
# [67]	validation_0-logloss:0.69783
# [68]	validation_0-logloss:0.70063
# [69]	validation_0-logloss:0.70312
# [70]	validation_0-logloss:0.70380
# [71]	validation_0-logloss:0.70522
# [72]	validation_0-logloss:0.70651
# [73]	validation_0-logloss:0.70941
# [74]	validation_0-logloss:0.71000
# [75]	validation_0-logloss:0.71213
# [76]	validation_0-logloss:0.71212
# [77]	validation_0-logloss:0.71408
# [78]	validation_0-logloss:0.71528
# [79]	validation_0-logloss:0.71751
# [80]	validation_0-logloss:0.71797
# [81]	validation_0-logloss:0.71929
# [82]	validation_0-logloss:0.72109
# [83]	validation_0-logloss:0.72337
# [84]	validation_0-logloss:0.72458
# [85]	validation_0-logloss:0.72596
# [86]	validation_0-logloss:0.72864
# [87]	validation_0-logloss:0.73046
# [88]	validation_0-logloss:0.73061
# [89]	validation_0-logloss:0.73213
# [90]	validation_0-logloss:0.73334
# [91]	validation_0-logloss:0.73488
# [92]	validation_0-logloss:0.73539
# [93]	validation_0-logloss:0.73740
# [94]	validation_0-logloss:0.73967
# [95]	validation_0-logloss:0.74071
# [96]	validation_0-logloss:0.74224
# [97]	validation_0-logloss:0.74366
# [98]	validation_0-logloss:0.74495
# [99]	validation_0-logloss:0.74555
# [0]	validation_0-logloss:0.56717
# [1]	validation_0-logloss:0.50110
# [2]	validation_0-logloss:0.46161
# [3]	validation_0-logloss:0.43791
# [4]	validation_0-logloss:0.42101
# [5]	validation_0-logloss:0.40691
# [6]	validation_0-logloss:0.39639
# [7]	validation_0-logloss:0.38798
# [8]	validation_0-logloss:0.38269
# [9]	validation_0-logloss:0.38128
# [10]	validation_0-logloss:0.37839
# [11]	validation_0-logloss:0.37445
# [12]	validation_0-logloss:0.36927
# [13]	validation_0-logloss:0.36727
# [14]	validation_0-logloss:0.36685
# [15]	validation_0-logloss:0.36510
# [16]	validation_0-logloss:0.36401
# [17]	validation_0-logloss:0.36306
# [18]	validation_0-logloss:0.36191
# [19]	validation_0-logloss:0.35964
# [20]	validation_0-logloss:0.35897
# [21]	validation_0-logloss:0.35625
# [22]	validation_0-logloss:0.35658
# [23]	validation_0-logloss:0.35642
# [24]	validation_0-logloss:0.35611
# [25]	validation_0-logloss:0.35559
# [26]	validation_0-logloss:0.35537
# [27]	validation_0-logloss:0.35489
# [28]	validation_0-logloss:0.35520
# [29]	validation_0-logloss:0.35366
# [30]	validation_0-logloss:0.35214
# [31]	validation_0-logloss:0.35183
# [32]	validation_0-logloss:0.35111
# [33]	validation_0-logloss:0.34984
# [34]	validation_0-logloss:0.35036
# [35]	validation_0-logloss:0.34998
# [36]	validation_0-logloss:0.34919
# [37]	validation_0-logloss:0.35026
# [38]	validation_0-logloss:0.34851
# [39]	validation_0-logloss:0.34887
# [40]	validation_0-logloss:0.34937
# [41]	validation_0-logloss:0.34994
# [42]	validation_0-logloss:0.35059
# [43]	validation_0-logloss:0.35021
# [44]	validation_0-logloss:0.35103
# [45]	validation_0-logloss:0.35050
# [46]	validation_0-logloss:0.35132
# [47]	validation_0-logloss:0.35175
# [48]	validation_0-logloss:0.35229
# [49]	validation_0-logloss:0.35408
# [50]	validation_0-logloss:0.35489
# [51]	validation_0-logloss:0.35484
# [52]	validation_0-logloss:0.35623
# [53]	validation_0-logloss:0.35762
# [54]	validation_0-logloss:0.35923
# [55]	validation_0-logloss:0.35942
# [56]	validation_0-logloss:0.35939
# [57]	validation_0-logloss:0.35991
# [58]	validation_0-logloss:0.36032
# [59]	validation_0-logloss:0.36063
# [60]	validation_0-logloss:0.36039
# [61]	validation_0-logloss:0.36249
# [62]	validation_0-logloss:0.36284
# [63]	validation_0-logloss:0.36393
# [64]	validation_0-logloss:0.36565
# [65]	validation_0-logloss:0.36634
# [66]	validation_0-logloss:0.36730
# [67]	validation_0-logloss:0.36651
# [68]	validation_0-logloss:0.36707
# [69]	validation_0-logloss:0.36847
# [70]	validation_0-logloss:0.36932
# [71]	validation_0-logloss:0.37089
# [72]	validation_0-logloss:0.37140
# [73]	validation_0-logloss:0.37171
# [74]	validation_0-logloss:0.37265
# [75]	validation_0-logloss:0.37357
# [76]	validation_0-logloss:0.37448
# [77]	validation_0-logloss:0.37423
# [78]	validation_0-logloss:0.37439
# [79]	validation_0-logloss:0.37529
# [80]	validation_0-logloss:0.37619
# [81]	validation_0-logloss:0.37702
# [82]	validation_0-logloss:0.37781
# [83]	validation_0-logloss:0.37926
# [84]	validation_0-logloss:0.38084
# [85]	validation_0-logloss:0.38138
# [86]	validation_0-logloss:0.38209
# [87]	validation_0-logloss:0.38254
# [88]	validation_0-logloss:0.38260
# [89]	validation_0-logloss:0.38379
# [90]	validation_0-logloss:0.38485
# [91]	validation_0-logloss:0.38558
# [92]	validation_0-logloss:0.38698
# [93]	validation_0-logloss:0.38792
# [94]	validation_0-logloss:0.38887
# [95]	validation_0-logloss:0.38975
# [96]	validation_0-logloss:0.39064
# [97]	validation_0-logloss:0.39120
# [98]	validation_0-logloss:0.39195
# [99]	validation_0-logloss:0.39258
# ---Oversampling XGBClassifier---
# ACC:  0.837
# F1:  0.3793
# ROC AUC:  0.6279
# PR:  0.4508
# ---Undersampling XGBClassifier---
# ACC:  0.7781
# F1:  0.5471
# ROC AUC:  0.8203
# PR:  0.3968
# ---Weighted-matrix XGBClassifier---
# ACC:  0.8478
# F1:  0.4684
# ROC AUC:  0.6807
# PR:  0.5
